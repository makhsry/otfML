# %% [markdown]
# #GDrive

# %%
from google.colab import drive
from google.colab import files
drive.mount('/content/drive/')
import os
# %cd /content/drive/My\ Drive/Collaboratory/
# Out:
# Mounted at /content/drive/
# /content/drive/My Drive/Collaboratory

# %% [markdown]
# #Imports

# %%
###############################################################################
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import BoundaryNorm
from matplotlib.ticker import MaxNLocator
###############################################################################

# %% [markdown]
# #Load data

# %%
kMC_intensities_300 = np.loadtxt("kMC_spectra_300.txt",  delimiter=",")
kMC_COEFF_300 = np.loadtxt("kMC_COEFF_300.txt",  delimiter=",")
kMC_intensities_325 = np.loadtxt("kMC_spectra_325.txt",  delimiter=",")
kMC_COEFF_325 = np.loadtxt("kMC_COEFF_325.txt",  delimiter=",")
kMC_intensities_350 = np.loadtxt("kMC_spectra_350.txt",  delimiter=",")
kMC_COEFF_350 = np.loadtxt("kMC_COEFF_350.txt",  delimiter=",")
kMC_intensities_375 = np.loadtxt("kMC_spectra_375.txt",  delimiter=",")
kMC_COEFF_375 = np.loadtxt("kMC_COEFF_375.txt",  delimiter=",")
kMC_intensities_400 = np.loadtxt("kMC_spectra_400.txt",  delimiter=",")
kMC_COEFF_400 = np.loadtxt("kMC_COEFF_400.txt",  delimiter=",")

# %% [markdown]
# #Plot Ramans

# %%
# Ramans 
#plt.rcParams.update({'font.size': 8})
SMALL_SIZE = 6
MEDIUM_SIZE = 8
BIGGER_SIZE = 10
plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=SMALL_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=SMALL_SIZE)  # fontsize of the figure title
# 
labelss = [
           'IBF', 
           'NCTA', 
           'CO-1', 
           'CO-2', 
           'CO-3', 
           'CO-4', 
           'CO-5', 
           'CO-6', 
           'CO-7', 
           'CO-8',
           'CO-9',  
           'DI-1',
           'DI-2',
           'DI-3',
           'DN-1',
           'DN-2',
           'DN-3',
           'DN-4', 
           'DN-5',
           'DN-6', 
           'DN-7', 
           'DN-8',
           'DN-9'
           ]
###############################################################################
cm = 1/2.54  # centimeters in inches
DPI = 900
fig, axs = plt.subplots(5, 1, figsize=(11*cm, 11*cm), dpi=DPI)
###############################################################################
dx, dy = 0.05, 0.05
y, x = np.meshgrid(np.linspace(0, 1, kMC_COEFF_300.shape[0]), \
                   np.array([300, 325, 350, 375, 400]))
###############################################################################
# 4,0 - 300 
resolution = 5000
MMM = kMC_intensities_300
mmm = kMC_COEFF_300
for item in range(kMC_intensities_300.shape[1]):
  MIN = np.min(kMC_intensities_300[:,item])
  if MIN == 0:
    MIN = 1e-8
  MAX = np.max(kMC_intensities_300[:,item])
  MMM[:,item] = \
  (kMC_intensities_300[:,item] - MIN) / (MAX - MIN) 
xs_cut_MIN = 0
xs_cut_MAX = 3700
CUTs = 1000
xs = np.linspace(xs_cut_MIN, xs_cut_MAX, CUTs)
#axs[0].set_xlabel('spectra 1/cm')
#axs[0].set_ylabel('intensity')
axs[0].set_xlim(400, 3700)
xline = xs
time = 0
up = 0
while (time < MMM.shape[1]):
  yline = time * np.ones((CUTs, 1))
  zline = MMM[:,time] + up
  up += np.max(MMM[:,time])
  axs[0].plot(xline, zline, linewidth=0.75)
  axs[0].yaxis.set_ticklabels([])
  for line in axs[0].yaxis.get_ticklines():
      line.set_visible(False)
  time += resolution
#axs[0].annotate("",
#            xy=(2000, 0.1), xycoords='data',
#            xytext=(2500, 15), textcoords='data',
#            arrowprops=dict(arrowstyle="<-",
#                            connectionstyle="arc3"),
#            )
#axs[0].text(2200, 7.5, "Incearing M", size=6, rotation=35,
#         ha="center", va="center",
#         )
axs[0].text(3400, 18, "T = 300K", size=6, ha="center", va="center",
         )
axs[0].xaxis.set_visible(False)
###############################################################################
# 4,1 - 325 
resolution = 5000
MMM = kMC_intensities_325
mmm = kMC_COEFF_325
for item in range(kMC_intensities_325.shape[1]):
  MIN = np.min(kMC_intensities_325[:,item])
  if MIN == 0:
    MIN = 1e-8
  MAX = np.max(kMC_intensities_325[:,item])
  MMM[:,item] = \
  (kMC_intensities_325[:,item] - MIN) / (MAX - MIN) 
xs_cut_MIN = 0
xs_cut_MAX = 3700
CUTs = 1000
xs = np.linspace(xs_cut_MIN, xs_cut_MAX, CUTs)
#axs[1].set_xlabel('spectra 1/cm')
#axs[1].set_ylabel('intensity')
axs[1].set_xlim(400, 3700)
xline = xs
time = 0
up = 0
while (time < MMM.shape[1]):
  yline = time * np.ones((CUTs, 1))
  zline = MMM[:,time] + up
  up += np.max(MMM[:,time])
  axs[1].plot(xline, zline, linewidth=0.75)
  axs[1].yaxis.set_ticklabels([])
  for line in axs[1].yaxis.get_ticklines():
      line.set_visible(False)
  time += resolution
#axs[1].annotate("",
#            xy=(2000, 0.1), xycoords='data',
#            xytext=(2500, 15), textcoords='data',
#            arrowprops=dict(arrowstyle="<-",
#                            connectionstyle="arc3"),
#            )
#axs[1].text(2200, 7.5, "Incearing M", size=6, rotation=35,
#         ha="center", va="center",
#         )
axs[1].text(3400, 18, "T = 325K", size=6, ha="center", va="center",
         )
axs[1].xaxis.set_visible(False)
###############################################################################
# 5,0 - 350
resolution = 5000
MMM = kMC_intensities_350
mmm = kMC_COEFF_350
for item in range(kMC_intensities_350.shape[1]):
  MIN = np.min(kMC_intensities_350[:,item])
  if MIN == 0:
    MIN = 1e-8
  MAX = np.max(kMC_intensities_350[:,item])
  MMM[:,item] = \
  (kMC_intensities_350[:,item] - MIN) / (MAX - MIN) 
xs_cut_MIN = 0
xs_cut_MAX = 3700
CUTs = 1000
xs = np.linspace(xs_cut_MIN, xs_cut_MAX, CUTs)
#axs[2].set_xlabel('spectra 1/cm')
axs[2].set_ylabel('intensity')
axs[2].set_xlim(400, 3700)
xline = xs
time = 0
up = 0
while (time < MMM.shape[1]):
  yline = time * np.ones((CUTs, 1))
  zline = MMM[:,time] + up
  up += np.max(MMM[:,time])
  axs[2].plot(xline, zline, linewidth=0.75)
  axs[2].yaxis.set_ticklabels([])
  for line in axs[2].yaxis.get_ticklines():
      line.set_visible(False)
  time += resolution
axs[2].annotate("",
            xy=(2000, 0.1), xycoords='data',
            xytext=(2500, 15), textcoords='data',
            arrowprops=dict(arrowstyle="<-",
                            connectionstyle="arc3"),
            )
axs[2].text(2200, 7.5, "Incearing M", size=6, rotation=35,
         ha="center", va="center",
         )
axs[2].text(3400, 18, "T = 350K", size=6, ha="center", va="center",
         )
axs[2].xaxis.set_visible(False)
###############################################################################
# 5,1 - 375
resolution = 5000
MMM = kMC_intensities_375
mmm = kMC_COEFF_375
for item in range(kMC_intensities_375.shape[1]):
  MIN = np.min(kMC_intensities_375[:,item])
  if MIN == 0:
    MIN = 1e-8
  MAX = np.max(kMC_intensities_375[:,item])
  MMM[:,item] = \
  (kMC_intensities_375[:,item] - MIN) / (MAX - MIN) 
xs_cut_MIN = 0
xs_cut_MAX = 3700
CUTs = 1000
xs = np.linspace(xs_cut_MIN, xs_cut_MAX, CUTs)
#axs[3].set_xlabel('spectra 1/cm')
#axs[3].set_ylabel('intensity')
axs[3].set_xlim(400, 3700)
xline = xs
time = 0
up = 0
while (time < MMM.shape[1]):
  yline = time * np.ones((CUTs, 1))
  zline = MMM[:,time] + up
  up += np.max(MMM[:,time])
  axs[3].plot(xline, zline, linewidth=0.75)
  axs[3].yaxis.set_ticklabels([])
  for line in axs[3].yaxis.get_ticklines():
      line.set_visible(False)
  time += resolution
#axs[3].annotate("",
#            xy=(2000, 0.1), xycoords='data',
#            xytext=(2500, 15), textcoords='data',
#            arrowprops=dict(arrowstyle="<-",
#                            connectionstyle="arc3"),
#            )
#axs[3].text(2200, 7.5, "Incearing M", size=6, rotation=35,
#         ha="center", va="center",
#         )
axs[3].text(3400, 18, "T = 375K", size=6, ha="center", va="center",
         )
axs[3].xaxis.set_visible(False)
###############################################################################
# 6,0 - 400
resolution = 5000
MMM = kMC_intensities_400
mmm = kMC_COEFF_400
for item in range(kMC_intensities_400.shape[1]):
  MIN = np.min(kMC_intensities_400[:,item])
  if MIN == 0:
    MIN = 1e-8
  MAX = np.max(kMC_intensities_400[:,item])
  MMM[:,item] = \
  (kMC_intensities_400[:,item] - MIN) / (MAX - MIN) 
xs_cut_MIN = 0
xs_cut_MAX = 3700
CUTs = 1000
xs = np.linspace(xs_cut_MIN, xs_cut_MAX, CUTs)
axs[4].set_xlabel('spectra 1/cm')
#axs[4].set_ylabel('intensity')
axs[4].set_xlim(400, 3700)
xline = xs
time = 0
up = 0
while (time < MMM.shape[1]):
  yline = time * np.ones((CUTs, 1))
  zline = MMM[:,time] + up
  up += np.max(MMM[:,time])
  axs[4].plot(xline, zline, linewidth=0.75)
  axs[4].yaxis.set_ticklabels([])
  for line in axs[4].yaxis.get_ticklines():
      line.set_visible(False)
  time += resolution
#axs[4].annotate("",
#            xy=(2000, 0.1), xycoords='data',
#            xytext=(2500, 15), textcoords='data',
#            arrowprops=dict(arrowstyle="<-",
#                            connectionstyle="arc3"),
#            )
#axs[4].text(2200, 7.5, "Incearing M", size=6, rotation=35,
#         ha="center", va="center",
#         )
axs[4].text(3400, 18, "T = 400K", size=6, ha="center", va="center",
         )
###############################################################################
#fig.suptitle('Fig. 2 (D)', x=0.175, y=0.905)
###############################################################################
plt.savefig('Figure2_dpi_'+str(DPI)+'_Ramans.pdf', bbox_inches='tight')

# %% [markdown]
# #Plot COs

# %%
# CO s
#plt.rcParams.update({'font.size': 8})
SMALL_SIZE = 6
MEDIUM_SIZE = 8
BIGGER_SIZE = 10
plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=SMALL_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=SMALL_SIZE)  # fontsize of the figure title
# 
labelss = [
           'IBF', 
           'NCTA', 
           'CO-1', 
           'CO-2', 
           'CO-3', 
           'CO-4', 
           'CO-5', 
           'CO-6', 
           'CO-7', 
           'CO-8',
           'CO-9',  
           'DI-1',
           'DI-2',
           'DI-3',
           'DN-1',
           'DN-2',
           'DN-3',
           'DN-4', 
           'DN-5',
           'DN-6', 
           'DN-7', 
           'DN-8',
           'DN-9'
           ]
###############################################################################
cm = 1/2.54  # centimeters in inches
DPI = 300
fig, axs = plt.subplots(5, 2, figsize=(17.5*cm, 20.5*cm), dpi=DPI)
###############################################################################
dx, dy = 0.05, 0.05
y, x = np.meshgrid(np.linspace(0, 1, kMC_COEFF_300.shape[0]), \
                   np.array([300, 325, 350, 375, 400]))
###############################################################################
pair = 2 #CO1
z = np.array([
                  kMC_COEFF_300[:,pair],
                  kMC_COEFF_325[:,pair],
                  kMC_COEFF_350[:,pair],
                  kMC_COEFF_375[:,pair],
                  kMC_COEFF_400[:,pair]])
z = z[:-1, :-1]
levels = MaxNLocator(nbins=15).tick_values(z.min(), z.max())
cmap = plt.get_cmap('RdBu')
norm = BoundaryNorm(levels, ncolors=cmap.N, clip=True)
im = axs[0,0].pcolormesh(x, y, z, cmap=cmap, norm=norm)
cbar = fig.colorbar(im, ax=axs[0,0])
cbar.set_label('fraction of ' + labelss[pair])
fig.tight_layout()
axs[0,0].axis([x.min(), x.max(), y.min(), y.max()])
axs[0,0].set_xlabel('Temperature [K]')
axs[0,0].set_ylabel('parameter M')
###############################################################################
pair = 3 #CO2
z = np.array([
                  kMC_COEFF_300[:,pair],
                  kMC_COEFF_325[:,pair],
                  kMC_COEFF_350[:,pair],
                  kMC_COEFF_375[:,pair],
                  kMC_COEFF_400[:,pair]])
z = z[:-1, :-1]
levels = MaxNLocator(nbins=15).tick_values(z.min(), z.max())
cmap = plt.get_cmap('RdBu')
norm = BoundaryNorm(levels, ncolors=cmap.N, clip=True)
im = axs[0,1].pcolormesh(x, y, z, cmap=cmap, norm=norm)
cbar = fig.colorbar(im, ax=axs[0,1])
cbar.set_label('fraction of ' + labelss[pair])
fig.tight_layout()
axs[0,1].axis([x.min(), x.max(), y.min(), y.max()])
axs[0,1].set_xlabel('Temperature [K]')
axs[0,1].set_ylabel('parameter M')
###############################################################################
pair = 4 #CO3
z = np.array([
                  kMC_COEFF_300[:,pair],
                  kMC_COEFF_325[:,pair],
                  kMC_COEFF_350[:,pair],
                  kMC_COEFF_375[:,pair],
                  kMC_COEFF_400[:,pair]])
z = z[:-1, :-1]
levels = MaxNLocator(nbins=15).tick_values(z.min(), z.max())
cmap = plt.get_cmap('RdBu')
norm = BoundaryNorm(levels, ncolors=cmap.N, clip=True)
im = axs[1,0].pcolormesh(x, y, z, cmap=cmap, norm=norm)
cbar = fig.colorbar(im, ax=axs[1,0])
cbar.set_label('fraction of ' + labelss[pair])
fig.tight_layout()
axs[1,0].axis([x.min(), x.max(), y.min(), y.max()])
axs[1,0].set_xlabel('Temperature [K]')
axs[1,0].set_ylabel('parameter M')
###############################################################################
pair = 5 #CO4
z = np.array([
                  kMC_COEFF_300[:,pair],
                  kMC_COEFF_325[:,pair],
                  kMC_COEFF_350[:,pair],
                  kMC_COEFF_375[:,pair],
                  kMC_COEFF_400[:,pair]])
z = z[:-1, :-1]
levels = MaxNLocator(nbins=15).tick_values(z.min(), z.max())
cmap = plt.get_cmap('RdBu')
norm = BoundaryNorm(levels, ncolors=cmap.N, clip=True)
im = axs[1,1].pcolormesh(x, y, z, cmap=cmap, norm=norm)
cbar = fig.colorbar(im, ax=axs[1,1])
cbar.set_label('fraction of ' + labelss[pair])
fig.tight_layout()
axs[1,1].axis([x.min(), x.max(), y.min(), y.max()])
axs[1,1].set_xlabel('Temperature [K]')
axs[1,1].set_ylabel('parameter M')
###############################################################################
pair = 6 #CO5
z = np.array([
                  kMC_COEFF_300[:,pair],
                  kMC_COEFF_325[:,pair],
                  kMC_COEFF_350[:,pair],
                  kMC_COEFF_375[:,pair],
                  kMC_COEFF_400[:,pair]])
z = z[:-1, :-1]
levels = MaxNLocator(nbins=15).tick_values(z.min(), z.max())
cmap = plt.get_cmap('RdBu')
norm = BoundaryNorm(levels, ncolors=cmap.N, clip=True)
im = axs[2,0].pcolormesh(x, y, z, cmap=cmap, norm=norm)
cbar = fig.colorbar(im, ax=axs[2,0])
cbar.set_label('fraction of ' + labelss[pair])
fig.tight_layout()
axs[2,0].axis([x.min(), x.max(), y.min(), y.max()])
axs[2,0].set_xlabel('Temperature [K]')
axs[2,0].set_ylabel('parameter M')
###############################################################################
pair = 7 #CO6
z = np.array([
                  kMC_COEFF_300[:,pair],
                  kMC_COEFF_325[:,pair],
                  kMC_COEFF_350[:,pair],
                  kMC_COEFF_375[:,pair],
                  kMC_COEFF_400[:,pair]])
z = z[:-1, :-1]
levels = MaxNLocator(nbins=15).tick_values(z.min(), z.max())
cmap = plt.get_cmap('RdBu')
norm = BoundaryNorm(levels, ncolors=cmap.N, clip=True)
im = axs[2,1].pcolormesh(x, y, z, cmap=cmap, norm=norm)
cbar = fig.colorbar(im, ax=axs[2,1])
cbar.set_label('fraction of ' + labelss[pair])
fig.tight_layout()
axs[2,1].axis([x.min(), x.max(), y.min(), y.max()])
axs[2,1].set_xlabel('Temperature [K]')
axs[2,1].set_ylabel('parameter M')
###############################################################################
pair = 8 #CO7
z = np.array([
                  kMC_COEFF_300[:,pair],
                  kMC_COEFF_325[:,pair],
                  kMC_COEFF_350[:,pair],
                  kMC_COEFF_375[:,pair],
                  kMC_COEFF_400[:,pair]])
z = z[:-1, :-1]
levels = MaxNLocator(nbins=15).tick_values(z.min(), z.max())
cmap = plt.get_cmap('RdBu')
norm = BoundaryNorm(levels, ncolors=cmap.N, clip=True)
im = axs[3,0].pcolormesh(x, y, z, cmap=cmap, norm=norm)
cbar = fig.colorbar(im, ax=axs[3,0])
cbar.set_label('fraction of ' + labelss[pair])
fig.tight_layout()
axs[3,0].axis([x.min(), x.max(), y.min(), y.max()])
axs[3,0].set_xlabel('Temperature [K]')
axs[3,0].set_ylabel('parameter M')
###############################################################################
pair = 9 #CO8
z = np.array([
                  kMC_COEFF_300[:,pair],
                  kMC_COEFF_325[:,pair],
                  kMC_COEFF_350[:,pair],
                  kMC_COEFF_375[:,pair],
                  kMC_COEFF_400[:,pair]])
z = z[:-1, :-1]
levels = MaxNLocator(nbins=15).tick_values(z.min(), z.max())
cmap = plt.get_cmap('RdBu')
norm = BoundaryNorm(levels, ncolors=cmap.N, clip=True)
im = axs[3,1].pcolormesh(x, y, z, cmap=cmap, norm=norm)
cbar = fig.colorbar(im, ax=axs[3,1])
cbar.set_label('fraction of ' + labelss[pair])
fig.tight_layout()
axs[3,1].axis([x.min(), x.max(), y.min(), y.max()])
axs[3,1].set_xlabel('Temperature [K]')
axs[3,1].set_ylabel('parameter M')
###############################################################################
pair = 10 #CO9
z = np.array([
                  kMC_COEFF_300[:,pair],
                  kMC_COEFF_325[:,pair],
                  kMC_COEFF_350[:,pair],
                  kMC_COEFF_375[:,pair],
                  kMC_COEFF_400[:,pair]])
z = z[:-1, :-1]
levels = MaxNLocator(nbins=15).tick_values(z.min(), z.max())
cmap = plt.get_cmap('RdBu')
norm = BoundaryNorm(levels, ncolors=cmap.N, clip=True)
im = axs[4,0].pcolormesh(x, y, z, cmap=cmap, norm=norm)
cbar = fig.colorbar(im, ax=axs[4,0])
cbar.set_label('fraction of ' + labelss[pair])
fig.tight_layout()
axs[4,0].axis([x.min(), x.max(), y.min(), y.max()])
axs[4,0].set_xlabel('Temperature [K]')
axs[4,0].set_ylabel('parameter M')
###############################################################################
fig.delaxes(axs[4,1]) 
###############################################################################
#fig.suptitle('Fig. 2 (A)', x=0.09, y=1.001)
###############################################################################
plt.savefig('Figure2_dpi_'+str(DPI)+'_COs.pdf', bbox_inches='tight')

# %% [markdown]
# #Plot DIs

# %%
# DIs
#plt.rcParams.update({'font.size': 8})
SMALL_SIZE = 6
MEDIUM_SIZE = 8
BIGGER_SIZE = 10
plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=SMALL_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=SMALL_SIZE)  # fontsize of the figure title
# 
labelss = [
           'IBF', 
           'NCTA', 
           'CO-1', 
           'CO-2', 
           'CO-3', 
           'CO-4', 
           'CO-5', 
           'CO-6', 
           'CO-7', 
           'CO-8',
           'CO-9',  
           'DI-1',
           'DI-2',
           'DI-3',
           'DN-1',
           'DN-2',
           'DN-3',
           'DN-4', 
           'DN-5',
           'DN-6', 
           'DN-7', 
           'DN-8',
           'DN-9'
           ]
###############################################################################
cm = 1/2.54  # centimeters in inches
DPI = 600
fig, axs = plt.subplots(3, 1, figsize=(5.75*cm, 8.75*cm), dpi=DPI)
###############################################################################
dx, dy = 0.05, 0.05
y, x = np.meshgrid(np.linspace(0, 1, kMC_COEFF_300.shape[0]), \
                   np.array([300, 325, 350, 375, 400]))
###############################################################################
pair = 11 # DI1
z = np.array([
                  kMC_COEFF_300[:,pair],
                  kMC_COEFF_325[:,pair],
                  kMC_COEFF_350[:,pair],
                  kMC_COEFF_375[:,pair],
                  kMC_COEFF_400[:,pair]])
z = z[:-1, :-1]
levels = MaxNLocator(nbins=15).tick_values(z.min(), z.max())
cmap = plt.get_cmap('RdBu')
norm = BoundaryNorm(levels, ncolors=cmap.N, clip=True)
im = axs[0].pcolormesh(x, y, z, cmap=cmap, norm=norm)
cbar = fig.colorbar(im, ax=axs[0])
cbar.set_label('fraction of ' + labelss[pair])
fig.tight_layout()
axs[0].axis([x.min(), x.max(), y.min(), y.max()])
axs[0].set_xlabel('Temperature [K]')
axs[0].set_ylabel('parameter M')
###############################################################################
pair = 12 # DI2
z = np.array([
                  kMC_COEFF_300[:,pair],
                  kMC_COEFF_325[:,pair],
                  kMC_COEFF_350[:,pair],
                  kMC_COEFF_375[:,pair],
                  kMC_COEFF_400[:,pair]])
z = z[:-1, :-1]
levels = MaxNLocator(nbins=15).tick_values(z.min(), z.max())
cmap = plt.get_cmap('RdBu')
norm = BoundaryNorm(levels, ncolors=cmap.N, clip=True)
im = axs[1].pcolormesh(x, y, z, cmap=cmap, norm=norm)
cbar = fig.colorbar(im, ax=axs[1])
cbar.set_label('fraction of ' + labelss[pair])
fig.tight_layout()
axs[1].axis([x.min(), x.max(), y.min(), y.max()])
axs[1].set_xlabel('Temperature [K]')
axs[1].set_ylabel('parameter M')
###############################################################################
pair = 13 # DI3
z = np.array([
                  kMC_COEFF_300[:,pair],
                  kMC_COEFF_325[:,pair],
                  kMC_COEFF_350[:,pair],
                  kMC_COEFF_375[:,pair],
                  kMC_COEFF_400[:,pair]])
z = z[:-1, :-1]
levels = MaxNLocator(nbins=15).tick_values(z.min(), z.max())
cmap = plt.get_cmap('RdBu')
norm = BoundaryNorm(levels, ncolors=cmap.N, clip=True)
im = axs[2].pcolormesh(x, y, z, cmap=cmap, norm=norm)
cbar = fig.colorbar(im, ax=axs[2])
cbar.set_label('fraction of ' + labelss[pair])
fig.tight_layout()
axs[2].axis([x.min(), x.max(), y.min(), y.max()])
axs[2].set_xlabel('Temperature [K]')
axs[2].set_ylabel('parameter M')
###############################################################################
#fig.delaxes(axs[1,1]) 
###############################################################################
#fig.suptitle('Fig. 2 (B)', x=0.25, y=1.0001)
###############################################################################
plt.savefig('Figure2_dpi_'+str(DPI)+'_DIs.pdf', bbox_inches='tight')

# %% [markdown]
# #Plot DNs

# %%
#plt.rcParams.update({'font.size': 8})
SMALL_SIZE = 6
MEDIUM_SIZE = 8
BIGGER_SIZE = 10
plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=SMALL_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=SMALL_SIZE)  # fontsize of the figure title
# 
labelss = [
           'IBF', 
           'NCTA', 
           'CO-1', 
           'CO-2', 
           'CO-3', 
           'CO-4', 
           'CO-5', 
           'CO-6', 
           'CO-7', 
           'CO-8',
           'CO-9',  
           'DI-1',
           'DI-2',
           'DI-3',
           'DN-1',
           'DN-2',
           'DN-3',
           'DN-4', 
           'DN-5',
           'DN-6', 
           'DN-7', 
           'DN-8',
           'DN-9'
           ]
###############################################################################
cm = 1/2.54  # centimeters in inches
DPI = 600
fig, axs = plt.subplots(5, 2, figsize=(17.5*cm, 20.5*cm), dpi=DPI)
###############################################################################
dx, dy = 0.05, 0.05
y, x = np.meshgrid(np.linspace(0, 1, kMC_COEFF_300.shape[0]), \
                   np.array([300, 325, 350, 375, 400]))
###############################################################################
pair = 14 # DN1
z = np.array([
                  kMC_COEFF_300[:,pair],
                  kMC_COEFF_325[:,pair],
                  kMC_COEFF_350[:,pair],
                  kMC_COEFF_375[:,pair],
                  kMC_COEFF_400[:,pair]])
z = z[:-1, :-1]
levels = MaxNLocator(nbins=15).tick_values(z.min(), z.max())
cmap = plt.get_cmap('RdBu')
norm = BoundaryNorm(levels, ncolors=cmap.N, clip=True)
im = axs[0,0].pcolormesh(x, y, z, cmap=cmap, norm=norm)
cbar = fig.colorbar(im, ax=axs[0,0])
cbar.set_label('fraction of ' + labelss[pair])
fig.tight_layout()
axs[0,0].axis([x.min(), x.max(), y.min(), y.max()])
axs[0,0].set_xlabel('Temperature [K]')
axs[0,0].set_ylabel('parameter M')
###############################################################################
pair = 15 # DN2
z = np.array([
                  kMC_COEFF_300[:,pair],
                  kMC_COEFF_325[:,pair],
                  kMC_COEFF_350[:,pair],
                  kMC_COEFF_375[:,pair],
                  kMC_COEFF_400[:,pair]])
z = z[:-1, :-1]
levels = MaxNLocator(nbins=15).tick_values(z.min(), z.max())
cmap = plt.get_cmap('RdBu')
norm = BoundaryNorm(levels, ncolors=cmap.N, clip=True)
im = axs[0,1].pcolormesh(x, y, z, cmap=cmap, norm=norm)
cbar = fig.colorbar(im, ax=axs[0,1])
cbar.set_label('fraction of ' + labelss[pair])
fig.tight_layout()
axs[0,1].axis([x.min(), x.max(), y.min(), y.max()])
axs[0,1].set_xlabel('Temperature [K]')
axs[0,1].set_ylabel('parameter M')
###############################################################################
pair = 16 # DN3
z = np.array([
                  kMC_COEFF_300[:,pair],
                  kMC_COEFF_325[:,pair],
                  kMC_COEFF_350[:,pair],
                  kMC_COEFF_375[:,pair],
                  kMC_COEFF_400[:,pair]])
z = z[:-1, :-1]
levels = MaxNLocator(nbins=15).tick_values(z.min(), z.max())
cmap = plt.get_cmap('RdBu')
norm = BoundaryNorm(levels, ncolors=cmap.N, clip=True)
im = axs[1,0].pcolormesh(x, y, z, cmap=cmap, norm=norm)
cbar = fig.colorbar(im, ax=axs[1,0])
cbar.set_label('fraction of ' + labelss[pair])
fig.tight_layout()
axs[1,0].axis([x.min(), x.max(), y.min(), y.max()])
axs[1,0].set_xlabel('Temperature [K]')
axs[1,0].set_ylabel('parameter M')
###############################################################################
pair = 17 # DN4
z = np.array([
                  kMC_COEFF_300[:,pair],
                  kMC_COEFF_325[:,pair],
                  kMC_COEFF_350[:,pair],
                  kMC_COEFF_375[:,pair],
                  kMC_COEFF_400[:,pair]])
z = z[:-1, :-1]
levels = MaxNLocator(nbins=15).tick_values(z.min(), z.max())
cmap = plt.get_cmap('RdBu')
norm = BoundaryNorm(levels, ncolors=cmap.N, clip=True)
im = axs[1,1].pcolormesh(x, y, z, cmap=cmap, norm=norm)
cbar = fig.colorbar(im, ax=axs[1,1])
cbar.set_label('fraction of ' + labelss[pair])
fig.tight_layout()
axs[1,1].axis([x.min(), x.max(), y.min(), y.max()])
axs[1,1].set_xlabel('Temperature [K]')
axs[1,1].set_ylabel('parameter M')
###############################################################################
pair = 18 # DN5
z = np.array([
                  kMC_COEFF_300[:,pair],
                  kMC_COEFF_325[:,pair],
                  kMC_COEFF_350[:,pair],
                  kMC_COEFF_375[:,pair],
                  kMC_COEFF_400[:,pair]])
z = z[:-1, :-1]
levels = MaxNLocator(nbins=15).tick_values(z.min(), z.max())
cmap = plt.get_cmap('RdBu')
norm = BoundaryNorm(levels, ncolors=cmap.N, clip=True)
im = axs[2,0].pcolormesh(x, y, z, cmap=cmap, norm=norm)
cbar = fig.colorbar(im, ax=axs[2,0])
cbar.set_label('fraction of ' + labelss[pair])
fig.tight_layout()
axs[2,0].axis([x.min(), x.max(), y.min(), y.max()])
axs[2,0].set_xlabel('Temperature [K]')
axs[2,0].set_ylabel('parameter M')
###############################################################################
pair = 19 # DN6
z = np.array([
                  kMC_COEFF_300[:,pair],
                  kMC_COEFF_325[:,pair],
                  kMC_COEFF_350[:,pair],
                  kMC_COEFF_375[:,pair],
                  kMC_COEFF_400[:,pair]])
z = z[:-1, :-1]
levels = MaxNLocator(nbins=15).tick_values(z.min(), z.max())
cmap = plt.get_cmap('RdBu')
norm = BoundaryNorm(levels, ncolors=cmap.N, clip=True)
im = axs[2,1].pcolormesh(x, y, z, cmap=cmap, norm=norm)
cbar = fig.colorbar(im, ax=axs[2,1])
cbar.set_label('fraction of ' + labelss[pair])
fig.tight_layout()
axs[2,1].axis([x.min(), x.max(), y.min(), y.max()])
axs[2,1].set_xlabel('Temperature [K]')
axs[2,1].set_ylabel('parameter M')
###############################################################################
pair = 20 # DN7
z = np.array([
                  kMC_COEFF_300[:,pair],
                  kMC_COEFF_325[:,pair],
                  kMC_COEFF_350[:,pair],
                  kMC_COEFF_375[:,pair],
                  kMC_COEFF_400[:,pair]])
z = z[:-1, :-1]
levels = MaxNLocator(nbins=15).tick_values(z.min(), z.max())
cmap = plt.get_cmap('RdBu')
norm = BoundaryNorm(levels, ncolors=cmap.N, clip=True)
im = axs[3,0].pcolormesh(x, y, z, cmap=cmap, norm=norm)
cbar = fig.colorbar(im, ax=axs[3,0])
cbar.set_label('fraction of ' + labelss[pair])
fig.tight_layout()
axs[3,0].axis([x.min(), x.max(), y.min(), y.max()])
axs[3,0].set_xlabel('Temperature [K]')
axs[3,0].set_ylabel('parameter M')
###############################################################################
pair = 21 # DN8
z = np.array([
                  kMC_COEFF_300[:,pair],
                  kMC_COEFF_325[:,pair],
                  kMC_COEFF_350[:,pair],
                  kMC_COEFF_375[:,pair],
                  kMC_COEFF_400[:,pair]])
z = z[:-1, :-1]
levels = MaxNLocator(nbins=15).tick_values(z.min(), z.max())
cmap = plt.get_cmap('RdBu')
norm = BoundaryNorm(levels, ncolors=cmap.N, clip=True)
im = axs[3,1].pcolormesh(x, y, z, cmap=cmap, norm=norm)
cbar = fig.colorbar(im, ax=axs[3,1])
cbar.set_label('fraction of ' + labelss[pair])
fig.tight_layout()
axs[3,1].axis([x.min(), x.max(), y.min(), y.max()])
axs[3,1].set_xlabel('Temperature [K]')
axs[3,1].set_ylabel('parameter M')
###############################################################################
pair = 22 # DN9
z = np.array([
                  kMC_COEFF_300[:,pair],
                  kMC_COEFF_325[:,pair],
                  kMC_COEFF_350[:,pair],
                  kMC_COEFF_375[:,pair],
                  kMC_COEFF_400[:,pair]])
z = z[:-1, :-1]
levels = MaxNLocator(nbins=15).tick_values(z.min(), z.max())
cmap = plt.get_cmap('RdBu')
norm = BoundaryNorm(levels, ncolors=cmap.N, clip=True)
im = axs[4,0].pcolormesh(x, y, z, cmap=cmap, norm=norm)
cbar = fig.colorbar(im, ax=axs[4,0])
cbar.set_label('fraction of ' + labelss[pair])
fig.tight_layout()
axs[4,0].axis([x.min(), x.max(), y.min(), y.max()])
axs[4,0].set_xlabel('Temperature [K]')
axs[4,0].set_ylabel('parameter M')
###############################################################################
fig.delaxes(axs[4,1])
###############################################################################
###############################################################################
#fig.suptitle('Fig. 2 (C)', x=0.09, y=1.001)
###############################################################################
plt.savefig('Figure2_dpi_'+str(DPI)+'_DNs.pdf', bbox_inches='tight')

# %% [markdown]
# #Saved

# %% [markdown]
# ##Plot Ramans

# %%
# Ramans 
#plt.rcParams.update({'font.size': 8})
SMALL_SIZE = 6
MEDIUM_SIZE = 8
BIGGER_SIZE = 10
plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=SMALL_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=SMALL_SIZE)  # fontsize of the figure title
# 
labelss = [
           'IBF', 
           'NCTA', 
           'CO-1', 
           'CO-2', 
           'CO-3', 
           'CO-4', 
           'CO-5', 
           'CO-6', 
           'CO-7', 
           'CO-8',
           'CO-9',  
           'DI-1',
           'DI-2',
           'DI-3',
           'DN-1',
           'DN-2',
           'DN-3',
           'DN-4', 
           'DN-5',
           'DN-6', 
           'DN-7', 
           'DN-8',
           'DN-9'
           ]
###############################################################################
cm = 1/2.54  # centimeters in inches
DPI = 600
fig, axs = plt.subplots(3, 2, figsize=(11*cm, 11*cm), dpi=DPI)
###############################################################################
dx, dy = 0.05, 0.05
y, x = np.meshgrid(np.linspace(0, 1, kMC_COEFF_300.shape[0]), \
                   np.array([300, 325, 350, 375, 400]))
###############################################################################
# 4,0 - 300 
resolution = 5000
MMM = kMC_intensities_300
mmm = kMC_COEFF_300
for item in range(kMC_intensities_300.shape[1]):
  MIN = np.min(kMC_intensities_300[:,item])
  if MIN == 0:
    MIN = 1e-8
  MAX = np.max(kMC_intensities_300[:,item])
  MMM[:,item] = \
  (kMC_intensities_300[:,item] - MIN) / (MAX - MIN) 
xs_cut_MIN = 0
xs_cut_MAX = 3700
CUTs = 1000
xs = np.linspace(xs_cut_MIN, xs_cut_MAX, CUTs)
axs[0,0].set_xlabel('spectra 1/cm')
axs[0,0].set_ylabel('intensity')
axs[0,0].set_xlim(400, 3700)
xline = xs
time = 0
up = 0
while (time < MMM.shape[1]):
  yline = time * np.ones((CUTs, 1))
  zline = MMM[:,time] + up
  up += np.max(MMM[:,time])
  axs[0,0].plot(xline, zline, linewidth=0.75)
  axs[0,0].yaxis.set_ticklabels([])
  for line in axs[0,0].yaxis.get_ticklines():
      line.set_visible(False)
  time += resolution
axs[0,0].annotate("",
            xy=(2000, 0.1), xycoords='data',
            xytext=(2500, 15), textcoords='data',
            arrowprops=dict(arrowstyle="<-",
                            connectionstyle="arc3"),
            )
axs[0,0].text(2200, 7.5, "Incearing M", size=6, rotation=70.,
         ha="center", va="center",
         )
axs[0,0].text(3250, 18, "T = 300K", size=6, ha="center", va="center",
         )
###############################################################################
# 4,1 - 325 
resolution = 5000
MMM = kMC_intensities_325
mmm = kMC_COEFF_325
for item in range(kMC_intensities_325.shape[1]):
  MIN = np.min(kMC_intensities_325[:,item])
  if MIN == 0:
    MIN = 1e-8
  MAX = np.max(kMC_intensities_325[:,item])
  MMM[:,item] = \
  (kMC_intensities_325[:,item] - MIN) / (MAX - MIN) 
xs_cut_MIN = 0
xs_cut_MAX = 3700
CUTs = 1000
xs = np.linspace(xs_cut_MIN, xs_cut_MAX, CUTs)
axs[0,1].set_xlabel('spectra 1/cm')
axs[0,1].set_ylabel('intensity')
axs[0,1].set_xlim(400, 3700)
xline = xs
time = 0
up = 0
while (time < MMM.shape[1]):
  yline = time * np.ones((CUTs, 1))
  zline = MMM[:,time] + up
  up += np.max(MMM[:,time])
  axs[0,1].plot(xline, zline, linewidth=0.75)
  axs[0,1].yaxis.set_ticklabels([])
  for line in axs[0,1].yaxis.get_ticklines():
      line.set_visible(False)
  time += resolution
axs[0,1].annotate("",
            xy=(2000, 0.1), xycoords='data',
            xytext=(2500, 15), textcoords='data',
            arrowprops=dict(arrowstyle="<-",
                            connectionstyle="arc3"),
            )
axs[0,1].text(2200, 7.5, "Incearing M", size=6, rotation=70.,
         ha="center", va="center",
         )
axs[0,1].text(3250, 18, "T = 325K", size=6, ha="center", va="center",
         )
###############################################################################
# 5,0 - 350
resolution = 5000
MMM = kMC_intensities_350
mmm = kMC_COEFF_350
for item in range(kMC_intensities_350.shape[1]):
  MIN = np.min(kMC_intensities_350[:,item])
  if MIN == 0:
    MIN = 1e-8
  MAX = np.max(kMC_intensities_350[:,item])
  MMM[:,item] = \
  (kMC_intensities_350[:,item] - MIN) / (MAX - MIN) 
xs_cut_MIN = 0
xs_cut_MAX = 3700
CUTs = 1000
xs = np.linspace(xs_cut_MIN, xs_cut_MAX, CUTs)
axs[1,0].set_xlabel('spectra 1/cm')
axs[1,0].set_ylabel('intensity')
axs[1,0].set_xlim(400, 3700)
xline = xs
time = 0
up = 0
while (time < MMM.shape[1]):
  yline = time * np.ones((CUTs, 1))
  zline = MMM[:,time] + up
  up += np.max(MMM[:,time])
  axs[1,0].plot(xline, zline, linewidth=0.75)
  axs[1,0].yaxis.set_ticklabels([])
  for line in axs[1,0].yaxis.get_ticklines():
      line.set_visible(False)
  time += resolution
axs[1,0].annotate("",
            xy=(2000, 0.1), xycoords='data',
            xytext=(2500, 15), textcoords='data',
            arrowprops=dict(arrowstyle="<-",
                            connectionstyle="arc3"),
            )
axs[1,0].text(2200, 7.5, "Incearing M", size=6, rotation=70.,
         ha="center", va="center",
         )
axs[1,0].text(3250, 18, "T = 350K", size=6, ha="center", va="center",
         )
###############################################################################
# 5,1 - 375
resolution = 5000
MMM = kMC_intensities_375
mmm = kMC_COEFF_375
for item in range(kMC_intensities_375.shape[1]):
  MIN = np.min(kMC_intensities_375[:,item])
  if MIN == 0:
    MIN = 1e-8
  MAX = np.max(kMC_intensities_375[:,item])
  MMM[:,item] = \
  (kMC_intensities_375[:,item] - MIN) / (MAX - MIN) 
xs_cut_MIN = 0
xs_cut_MAX = 3700
CUTs = 1000
xs = np.linspace(xs_cut_MIN, xs_cut_MAX, CUTs)
axs[1,1].set_xlabel('spectra 1/cm')
axs[1,1].set_ylabel('intensity')
axs[1,1].set_xlim(400, 3700)
xline = xs
time = 0
up = 0
while (time < MMM.shape[1]):
  yline = time * np.ones((CUTs, 1))
  zline = MMM[:,time] + up
  up += np.max(MMM[:,time])
  axs[1,1].plot(xline, zline, linewidth=0.75)
  axs[1,1].yaxis.set_ticklabels([])
  for line in axs[1,1].yaxis.get_ticklines():
      line.set_visible(False)
  time += resolution
axs[1,1].annotate("",
            xy=(2000, 0.1), xycoords='data',
            xytext=(2500, 15), textcoords='data',
            arrowprops=dict(arrowstyle="<-",
                            connectionstyle="arc3"),
            )
axs[1,1].text(2200, 7.5, "Incearing M", size=6, rotation=70.,
         ha="center", va="center",
         )
axs[1,1].text(3250, 18, "T = 375K", size=6, ha="center", va="center",
         )
###############################################################################
# 6,0 - 400
resolution = 5000
MMM = kMC_intensities_400
mmm = kMC_COEFF_400
for item in range(kMC_intensities_400.shape[1]):
  MIN = np.min(kMC_intensities_400[:,item])
  if MIN == 0:
    MIN = 1e-8
  MAX = np.max(kMC_intensities_400[:,item])
  MMM[:,item] = \
  (kMC_intensities_400[:,item] - MIN) / (MAX - MIN) 
xs_cut_MIN = 0
xs_cut_MAX = 3700
CUTs = 1000
xs = np.linspace(xs_cut_MIN, xs_cut_MAX, CUTs)
axs[2,0].set_xlabel('spectra 1/cm')
axs[2,0].set_ylabel('intensity')
axs[2,0].set_xlim(400, 3700)
xline = xs
time = 0
up = 0
while (time < MMM.shape[1]):
  yline = time * np.ones((CUTs, 1))
  zline = MMM[:,time] + up
  up += np.max(MMM[:,time])
  axs[2,0].plot(xline, zline, linewidth=0.75)
  axs[2,0].yaxis.set_ticklabels([])
  for line in axs[2,0].yaxis.get_ticklines():
      line.set_visible(False)
  time += resolution
axs[2,0].annotate("",
            xy=(2000, 0.1), xycoords='data',
            xytext=(2500, 15), textcoords='data',
            arrowprops=dict(arrowstyle="<-",
                            connectionstyle="arc3"),
            )
axs[2,0].text(2200, 7.5, "Incearing M", size=6, rotation=70,
         ha="center", va="center",
         )
axs[2,0].text(3250, 18, "T = 400K", size=6, ha="center", va="center",
         )
###############################################################################
fig.delaxes(axs[2,1]) 
###############################################################################
fig.suptitle('Fig. 2 (D)', x=0.175, y=0.905)
###############################################################################
#plt.savefig('Figure2_dpi_'+str(DPI)+'_Ramans.pdf', bbox_inches='tight')
